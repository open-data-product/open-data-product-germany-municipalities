# %% [markdown]
# # Municipalities - Sample Notebook

# %% [markdown]
# ## Explore data

# %%
import pandas as pd

# Read csv file
dataframe = pd.read_csv(
    "./data/03-gold/germany-municipalities-2026-03-csv/germany-municipalities-2026-03.csv"
)

# %%
# Display 5 first rows
dataframe.head()

# %%
# Display dataframe info
dataframe.info()

# %%
# Describe dataframe
dataframe.describe()
